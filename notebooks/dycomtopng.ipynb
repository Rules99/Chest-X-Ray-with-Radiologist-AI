# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
from pydicom import dcmread
import cv2
from pydicom.pixel_data_handlers import apply_modality_lut, apply_voi_lut
import os
import png

# %%
my_route = '../../OneDrive/Documents/Documentos/physionet.org/files/mimic-cxr/2.0.0'
os.chdir(my_route)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19000/195891567.py in <module>
#       1 my_route = '../../OneDrive/Documents/Documentos/physionet.org/files/mimic-cxr/2.0.0'
# ----> 2 os.chdir(my_route)
#
# FileNotFoundError: [WinError 3] El sistema no puede encontrar la ruta especificada: '../../OneDrive/Documents/Documentos/physionet.org/files/mimic-cxr/2.0.0'

# %%
from pydicom.pixel_data_handlers import apply_modality_lut, apply_voi_lut
def preprocesimg(dcm_file,thr =  5):
        # Load DICOM image
        ds = dcmread(dcm_file)

        # Verify orientation
        # if ds.ViewPosition != 'AP' and ds.ViewPosition != 'PA':
            

        # Apply transformations if required
        if ds.pixel_array.dtype != np.uint8:
            # Apply LUT transforms
            arr = apply_modality_lut(ds.pixel_array, ds)
            if arr.dtype == np.float64 and ds.RescaleSlope == 1 and ds.RescaleIntercept == 0:
                arr = arr.astype(np.uint16)
            arr = apply_voi_lut(arr, ds)
            arr = arr.astype(np.float64)

            # Normalize to [0, 1]
            arr = (arr - arr.min())/arr.ptp()

            # Invert MONOCHROME1 images
            if ds.PhotometricInterpretation == 'MONOCHROME1':
                print('PHOTOMETRIC')
                arr = 1. - arr
            # Convert to uint8
            image = np.uint8(255.*arr)
        else:
            # Invert MONOCHROME1 imagesA
            if ds.PhotometricInterpretation == 'MONOCHROME1':
                image = 255 - ds.pixel_array
            else:
                image = ds.pixel_array

        _,thresh = cv2.threshold(image,image.min(),image.max(),cv2.THRESH_BINARY)
        # Cut the countours of the image
        contours,hierarchy = cv2.findContours(thresh,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)
        cnt = contours[0]
        # Choose the vertex of the image 
        x,y,w,h = cv2.boundingRect(cnt)
        png_file = dcm_file[:dcm_file.find('.dcm')]+'.png'
        if ((arr.shape[0]//thr)>w) or (((arr.shape[1]//thr)>h)):
            cv2.imwrite(png_file,image)
        else:
            cv2.imwrite(png_file,image[y:y+h,x:x+w])
        # Write the PNG file
        # with open(f'{dcm_file.strip(".dcm")}.png', 'wb') as png_file:
        #     w = png.Writer(ds.pixel_array.shape[1], ds.pixel_array.shape[0], greyscale=True)
        #     w.write(png_file, image)
        os.remove(dcm_file)

# %%
f"{'aiwpgbaergbslñd.dcm'.strip('.dcm')}.png"
# Out:
# 'aiwpgbaergbslñ.png'

# %%
df = pd.read_csv(f'./dicom_reports_labels.csv')

# %%
 def checkdfpaths(df):
        '''
        Check if there is an image that does not exist
        param : df (pd.DataFrame) dataframe of paths and labels
        '''
        # Check that all paths have dycom files
        notpaths = list()
        for path in df.path_x:
            # If image exists the file will be read correctly
            try:
                dcmread(path)
            # Otherwise we won' t find the image there it will not exist and we will delete the image from main dataframe
            except FileNotFoundError:
                notpaths.append(path)
        return notpaths

# %%
notpaths = checkdfpaths(df)

# %%
df[~df.path_x.isin(notpaths)].to_csv('./dicom_reports_labels.csv',index=False)

# %%
def preprocessimages(df):
    for path in df.path_x:
        preprocesimg(path)
    df['path_x'] =df.path_x.apply(lambda x: f"{x.strip('.dcm')}.png")
    return df

# %%
new_df = preprocessimages(df)
# Out:
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# PHOTOMETRIC
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19000/124516274.py in <module>
# ----> 1 new_df = preprocessimages(df)
#
# ~\AppData\Local\Temp/ipykernel_19000/1491415163.py in preprocessimages(df)
#       2     for path in df.path_x:
#       3         preprocesimg(path)
# ----> 4     df.path_x.apply(lambda x: f"{path.strip('.dcm')}.png",axis = 0)
#       5     return df
#
# ~\anaconda3\envs\mlimage\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4428         dtype: float64
#    4429         """
# -> 4430         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4431
#    4432     def _reduce(
#
# ~\anaconda3\envs\mlimage\lib\site-packages\pandas\core\apply.py in apply(self)
#    1080             return self.apply_str()
#    1081
# -> 1082         return self.apply_standard()
#    1083
#    1084     def agg(self):
#
# ~\anaconda3\envs\mlimage\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#    1135                 # List[Union[Callable[..., Any], str]]]]]"; expected
#    1136                 # "Callable[[Any], Any]"
# -> 1137                 mapped = lib.map_infer(
#    1138                     values,
#    1139                     f,  # type: ignore[arg-type]
#
# ~\anaconda3\envs\mlimage\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# ~\anaconda3\envs\mlimage\lib\site-packages\pandas\core\apply.py in f(x)
#     136
#     137             def f(x):
# --> 138                 return func(x, *args, **kwargs)
#     139
#     140         else:
#
# TypeError: <lambda>() got an unexpected keyword argument 'axis'

# %%
# df.to_csv(f'./dicom_reports_labels.csv',index = False)
